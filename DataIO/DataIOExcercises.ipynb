# %%
# %pylab inline
import numpy as np
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['f']
# `%matplotlib` prevents importing * from pylab and numpy

# %% [markdown]
# 1. Here is some code that creates a comma-delimited file of numbers with random precision, leading spaces, and formatting:

# %%
# Don't modify this: it simply writes the example file
f = open('messy_data.dat', 'w')
import random
for i in range(100):
    for j in range(5):
        f.write(' ' * random.randint(0, 6))
        f.write('%0*.*g' % (random.randint(8, 12),
                            random.randint(5, 10),
                            100 * random.random()))
        if j != 4:
            f.write(',')
    f.write('\n')
f.close()

# %% [markdown]
# (a) Write a program that reads in the contents of "messy_data.dat" and extracts the numbers from each line, using the string manipulations we used in section 1 (remember that float() will convert a suitable string to a floating-point number).

# %%
a = open('messy_data.dat').read()
b = open('messy1_data.dat', 'w')
b.write(a.replace(',', ' '))
b.close()
c = []
for line in open('messy1_data.dat'):
    d = line.split()
    for i in d:
        c.append(float(i))
print c
# Out:
# [80.54574, 99.9982156, 25.5963124, 45.258495, 71.33978656, 42.731, 60.07604561, 1.027, 32.19869, 21.5495119, 49.1656, 54.2437, 20.18146604, 62.9834, 13.81593, 21.979466, 48.9490211, 49.4795, 37.323, 57.532, 17.2023, 12.60449478, 6.146, 44.80428392, 42.209453, 49.228, 62.484575, 34.4166852, 40.56414, 77.83247, 86.6784331, 61.532, 58.2715, 22.16632301, 17.0145004, 59.267, 11.359789, 14.28880495, 18.02958, 96.9785, 46.60760616, 75.89743, 79.31210526, 5.0876508, 8.288516499, 27.86311, 76.314253, 56.8568, 64.2755611, 71.4953898, 11.1825, 73.3509003, 28.188079, 47.37, 87.731114, 77.5963336, 16.369, 58.474, 83.282, 52.283239, 79.1372, 12.589, 80.8312692, 33.30616289, 73.616, 76.825, 30.548, 48.41, 82.00063, 48.5938, 97.9724849, 54.1789765, 98.3149, 3.27545, 58.68711771, 18.498, 63.64568, 57.312, 10.76336975, 87.3624, 70.9997, 69.97, 83.8506563, 61.366, 73.74008, 3.61468, 84.6548143, 13.0790142, 98.81740544, 5.98759, 2.72642772, 44.54888414, 15.5732827, 59.095, 84.324803, 57.162, 66.39141295, 66.27832, 92.16757, 6.03855, 20.34848, 82.382, 72.3875961, 50.134351, 5.45531, 19.295, 37.54306237, 31.76, 53.1584599, 8.82096112, 40.230213, 19.674, 31.91513956, 81.0136973, 58.826712, 97.6078, 40.51509259, 11.5297, 26.6313, 65.403, 22.26593865, 38.2753967, 74.18868349, 33.604, 96.563572, 91.11328, 11.2530957, 80.222, 86.5048369, 52.378134, 61.2792939, 25.7259358, 95.62881, 96.25542313, 15.080396, 93.84835138, 48.435, 35.6046, 57.324, 5.846068, 11.508, 70.1603824, 10.0511, 51.9220859, 66.57816, 76.26758, 66.6909, 56.33593, 12.214, 72.367073, 13.709805, 47.5149, 77.38185, 96.562, 32.2564865, 11.9641, 44.26033, 59.593, 63.06, 51.4142677, 78.4485, 29.9557, 74.1543258, 46.2817316, 7.036869, 28.5789455, 73.1400224, 29.647, 83.60763, 72.5042, 12.5791, 48.602908, 21.409, 67.23872286, 97.0493, 36.15456934, 22.3655325, 89.0167124, 36.43778, 67.4874401, 29.460671, 17.292121, 79.9029323, 74.6818866, 61.051741, 92.510476, 40.6716508, 85.664, 49.8628901, 57.989, 39.503, 41.0608095, 92.19587779, 42.21624554, 9.85245404, 40.8515, 5.911490211, 22.7086, 10.916736, 6.571578, 23.03192465, 92.32901561, 36.71664, 74.181, 2.55777, 99.98482067, 54.258, 11.1213, 15.18816352, 33.351, 74.26710382, 95.9185, 88.0494889, 18.9604, 98.33052, 10.993931, 51.1796, 5.9941693, 5.08161, 41.003, 1.741418, 64.309119, 97.545, 68.81977, 64.37118887, 31.26931014, 14.805, 67.02881734, 29.02129, 66.84317, 34.151804, 23.999067, 77.0697621, 90.55935, 34.649, 99.749, 40.6544627, 56.17847, 96.808423, 39.0092, 44.74633, 34.9713468, 34.829234, 20.1812163, 81.1362086, 55.1374055, 34.2204773, 36.550207, 18.19232434, 3.926543, 43.502, 40.4267, 50.936, 53.22569128, 93.08895, 71.426, 21.575, 11.202431, 50.5517, 33.6387, 27.5592293, 53.0209468, 6.18682, 71.575, 36.6068664, 44.611, 79.47410155, 73.365, 64.2771275, 22.822, 23.602, 64.433, 71.88547, 42.662, 14.314, 43.134, 83.8304042, 28.26354, 67.657, 26.5140614, 31.4941396, 11.9785, 47.4442108, 79.1070967, 90.226708, 38.3828, 5.3459671, 44.5334772, 49.123956, 53.64334671, 73.0401, 54.436956, 88.9499075, 91.04579, 2.97305111, 71.659, 31.10842981, 89.4709, 80.029892, 37.268848, 76.067, 30.773, 87.328415, 58.639464, 40.9960267, 33.5599996, 74.7713, 95.3888286, 45.513, 88.97834, 87.729, 87.815, 6.47805806, 18.2112333, 69.06245, 1.5934, 59.172208, 55.576, 45.50357, 36.51564, 28.756607, 54.04543273, 4.6915, 33.73, 90.4204989, 88.79152, 91.803377, 7.695922546, 15.4962699, 70.503, 60.782048, 39.95841155, 3.789917234, 78.557888, 32.159223, 24.0148704, 88.78303411, 92.56638822, 3.271857819, 0.75378356, 4.08715071, 56.2843027, 80.452, 26.19394208, 0.038829, 27.6092706, 94.78529, 34.249319, 98.31498399, 20.394581, 16.822785, 28.466, 83.5763, 55.7554716, 28.958, 73.52699, 8.3327, 31.397, 92.9693, 50.90267, 86.2927843, 79.383, 36.148736, 98.31971, 19.1253496, 93.4422, 95.6817, 64.169, 4.21603, 83.347, 5.975890881, 26.5448, 26.82816712, 76.491, 94.3982, 73.259101, 33.3392, 82.132658, 10.22933275, 63.73808, 92.761, 64.249786, 3.94262992, 1.12978, 99.67, 74.37771, 46. ...

# %% [markdown]
# (b) Next write out a new file named "clean_data.dat". The new file should contain the same data as the old file, but with uniform formatting and aligned columns.

# %%
array1 = np.array(c)
array2 = array1.reshape(400, 5)
print array2
# Out:
# [[ 80.54574     99.9982156   25.5963124   45.258495    71.33978656]
#  [ 42.731       60.07604561   1.027       32.19869     21.5495119 ]
#  [ 49.1656      54.2437      20.18146604  62.9834      13.81593   ]
#  ...,
#  [ 43.795947    63.094        7.16744525  11.46        28.34646   ]
#  [ 96.500976    48.54417959  92.32774     92.66        73.13132347]
#  [ 79.0114703   13.23315407  16.09392     99.58206111  39.1494421 ]]

# %% [markdown]
# (c) Now re-do the same task using NumPy's loadtxt and savetxt functions.

# %%
a = loadtxt('messy1_data.dat', unpack = True, delimiter=",", usecols = [400,5])
print a

savetxt("clean_data.dat", a)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-27-a33a10c926d6> in <module>()
# ----> 1 a = loadtxt('messy1_data.dat', unpack = True, delimiter=",", usecols = [400,5])
#       2 print a
#       3
#       4 savetxt("clean_data.dat", a)
#
# C:\Users\masha\Anaconda\lib\site-packages\numpy\lib\npyio.pyc in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin)
#     839                 continue
#     840             if usecols:
# --> 841                 vals = [vals[i] for i in usecols]
#     842             # Convert each value according to its column and store
#     843             items = [conv(val) for (conv, val) in zip(converters, vals)]
#
# IndexError: list index out of range
