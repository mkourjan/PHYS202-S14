# %%
from ipythonblocks import BlockGrid
grid = BlockGrid(10, 10, fill=(173, 216, 230))
grid.show()



from random import randint

board = []

for x in range(10):
    board.append(["O"] * 10)

def print_board(board):
    for row in board:
        print " ".join(row)

print "Let's play Battleship!"
print_board(board)

def random_row1(board):
    X = randint(0, len(board) - 1)
    return X
    def random_row2(board):
        return X + 1

    def random_col(board):
        return randint(0, len(board[0]) - 1)

    ship_row1 = random_row1(board)
    ship_row2 = random_row2(board)
    ship_col = random_col(board)
    print ship_row1
    print ship_row2
    print ship_col

# Everything from here on should go in your for loop!
# Be sure to indent four spaces!
for turn in range(11):
    guess_row = int(raw_input("Guess Row:"))
    guess_col = int(raw_input("Guess Col:"))

    if (guess_row == ship_row1 or guess_row == ship_row2) and guess_col == ship_col:
        print "Congratulations! You sunk my battleship!"
        board[guess_row1][guess_col] = "Y"
        board[guess_row2][guess_col] = "Y"
        grid[guess_row1, guess_col] = (255, 0, 0)
        grid[guess_row2, guess_col] = (255, 0, 0)
        grid.show()
        
        break 
    else:
        if (guess_row1 < 0 or guess_row1 > 11) or (guess_col < 0 or guess_col > 11) or (guess_row2 < 0 or guess_row2 > 11):
            print "Oops, that's not even in the ocean."
        elif(board[(guess_row1) or (guess_row2)][guess_col] == "X"):
            print "You guessed that one already."
        else:
            print "You missed my battleship!"
            board[(guess_row1) or (guess_row2)][guess_col] = "X"
            grid[guess_row1, guess_col] = (139, 0, 139)
            grid[guess_row2, guess_col] = (139, 0, 139)
            grid.show()
            if turn == 10:
                print "Game Over"
    # Print (turn + 1) here!
    print "turn", (turn + 1)
    print_board(board)
# Out:
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks8b6cbe81-4192-4350-83b1-b908b30d771a td {border: 1px solid white;}</style><table id="blocks8b6cbe81-4192-4350-83b1-b908b30d771a" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 1]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 2]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 3]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 4]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 5]&#10;Color: (173, 216, 230)" style="width: 2
# ...

# %%
from random import randint

board = []

for x in range(10):
    board.append(["O"] * 10)

    def print_board(board):
        for row in board:
            print " ".join(row)

    print "Let's play Battleship!"
    print_board(board)

    def random_row1(board):
        return randint(0, len(board) - 1)
# Out:
# Let's play Battleship!
# O O O O O O O O O O
# Let's play Battleship!
# O O O O O O O O O O
# O O O O O O O O O O
# Let's play Battleship!
# O O O O O O O O O O
# O O O O O O O O O O
# O O O O O O O O O O
# Let's play Battleship!
# O O O O O O O O O O
# O O O O O O O O O O
# O O O O O O O O O O
# O O O O O O O O O O
# Let's play Battleship!
# O O O O O O O O O O
# O O O O O O O O O O
# O O O O O O O O O O
# O O O O O O O O O O
# O O O O O O O O O O
# Let's play Battleship!
# O O O O O O O O O O
# O O O O O O O O O O
# O O O O O O O O O O
# O O O O O O O O O O
# O O O O O O O O O O
# O O O O O O O O O O
# Let's play Battleship!
# O O O O O O O O O O
# O O O O O O O O O O
# O O O O O O O O O O
# O O O O O O O O O O
# O O O O O O O O O O
# O O O O O O O O O O
# O O O O O O O O O O
# Let's play Battleship!
# O O O O O O O O O O
# O O O O O O O O O O
# O O O O O O O O O O
# O O O O O O O O O O
# O O O O O O O O O O
# O O O O O O O O O O
# O O O O O O O O O O
# O O O O O O O O O O
# ...

# %%
from ipythonblocks import BlockGrid
grid = BlockGrid(10, 10, fill=(173, 216, 230))
grid.show()



from random import randint

board = []

for x in range(10):
    board.append(["O"] * 10)

    def print_board(board):
        for row in board:
            print " ".join(row)

    print "Let's play Battleship!"
    print_board(board)

    def random_row(board):
        return randint(0, len(board) - 1)
        
    def random_col(board):
        return randint(0, len(board[0]) - 1)

    ship_row = random_row1(board)
        
    ship_col = random_col(board)
    print ship_row
        
    print ship_col

# Everything from here on should go in your for loop!
# Be sure to indent four spaces!
    for turn in range(11):
        guess_row = int(raw_input("Guess Row:"))
        guess_col = int(raw_input("Guess Col:"))

        if (guess_row == ship_row) and guess_col == ship_col:
            print "Congratulations! You sunk my battleship!"
            board[guess_row][guess_col] = "Y"
            
            grid[guess_row, guess_col] = (255, 0, 0)
            
            grid.show()
            
            break 
        else:
            if (guess_row < 0 or guess_row > 11) or (guess_col < 0 or guess_col > 11):
                print "Oops, that's not even in the ocean."
            elif(board[(guess_row)][guess_col] == "X"):
                print "You guessed that one already."
            else:
                print "You missed my battleship!"
                board[guess_row][guess_col] = "X"
                grid[guess_row, guess_col] = (139, 0, 139)
                
                grid.show()
                if turn == 10:
                    print "Game Over"
    # Print (turn + 1) here!
        print "turn", (turn + 1)
        print_board(board)
# Out:
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocksfe069ab5-78fe-4d73-8c8f-440e228a65b0 td {border: 1px solid white;}</style><table id="blocksfe069ab5-78fe-4d73-8c8f-440e228a65b0" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 1]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 2]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 3]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 4]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 5]&#10;Color: (173, 216, 230)" style="width: 2
# ...

# %%
from ipythonblocks import BlockGrid
grid = BlockGrid(10, 10, fill=(173, 216, 230))
grid.show()


from random import randint

board = []

for x in range(11):
    board.append(["O"] * 10)

def print_board(board):
    for row in board:
        print " ".join(row)

print "Let's play Battleship!"


def random_row(board):
    return randint(0, len(board) - 1)
    
def random_col(board):
    return randint(0, len(board[0]) - 1)
    
ship_row = random_row(board)
ship_col = random_col(board)
print ship_row
print ship_col
    
    # Everything from here on should go in your for loop!
    # Be sure to indent four spaces!
for turn in range(10):
    guess_row = int(raw_input("Guess Row:"))
    guess_col = int(raw_input("Guess Col:"))
    
    if guess_row == ship_row and guess_col == ship_col:
        print "Congratulations! You sunk my battleship!"
        board[guess_row][guess_col] = "Y"
        grid[guess_row, guess_col] = (255, 0, 0)
        grid.show()
        break 
    else:
        if (guess_row < 0 or guess_row > 4) or (guess_col < 0 or guess_col > 4):
            print "Oops, that's not even in the ocean."
        elif(board[guess_row][guess_col] == "X"):
            print "You guessed that one already."
        else:
            print "You missed my battleship!"
            board[guess_row][guess_col] = "X"
            grid[guess_row, guess_col] = (70, 130, 180)
            grid.show()
            if turn == 3:
                print "Game Over"
        # Print (turn + 1) here!
        print "turn", (turn + 1)
        print_board(board)
# Out:
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks63ee9db4-8278-4c3f-80e6-f8af5d0af1f4 td {border: 1px solid white;}</style><table id="blocks63ee9db4-8278-4c3f-80e6-f8af5d0af1f4" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 1]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 2]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 3]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 4]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 5]&#10;Color: (173, 216, 230)" style="width: 2
# ...

# %%
from ipythonblocks import BlockGrid
grid = BlockGrid(10, 10, fill=(173, 216, 230))
grid.show()


from random import randint

board = []

for x in range(11):
    board.append(["O"] * 10)

def print_board(board):
    for row in board:
        print " ".join(row)

print "Let's play Battleship!"


def random_row(board):
    S = randint(1, len(board) - 1)
    return S, S + 1, S + 2, S + 3
    
def random_col(board):
    return randint(1, len(board[0]) - 1)
    
ship_row = random_row(board)
ship_col = random_col(board)

    
    # Everything from here on should go in your for loop!
    # Be sure to indent four spaces!
for turn in range(11):
    guess_row = int(raw_input("Guess Row:"))
    guess_col = int(raw_input("Guess Col:"))
    
    if guess_row in ship_row and guess_col == ship_col:
        print "Congratulations! You sunk my battleship!"
        
        board[guess_row][guess_col] = "Y"
        
        grid[guess_row, guess_col] = (255, 0, 0)
        grid.show()
         
    else:
        if (guess_row < 0 or guess_row > 10) or (guess_col < 0 or guess_col > 10):
            print "Oops, that's not even in the ocean."
        elif(board[guess_row][guess_col] == "X"):
            print "You guessed that one already."
        else:
            print "You missed my battleship!"
            board[guess_row][guess_col] = "X"
            grid[guess_row, guess_col] = (70, 130, 180)
            grid.show()
            if turn == 10:
                print "Game Over"
                print ship_row
                print ship_col
        # Print (turn + 1) here!
        print "turn", (turn + 1)
# Out:
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks7f9e4f82-8e5b-4f64-9251-e81294cc59f6 td {border: 1px solid white;}</style><table id="blocks7f9e4f82-8e5b-4f64-9251-e81294cc59f6" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 1]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 2]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 3]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 4]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 5]&#10;Color: (173, 216, 230)" style="width: 2
# ...

# %%
from ipythonblocks import BlockGrid
grid = BlockGrid(10, 10, fill=(173, 216, 230))
grid.show()

# %% [markdown]
# I imported the python blocks onto my ipython!

# %%
from random import randint

board = []

for x in range(11):
    board.append(["O"] * 10)

def print_board(board):
    for row in board:
        print " ".join(row)

print "Let's play Battleship!"


def random_row(board):
    S = randint(1, len(board) - 1)
    return S, S + 1, S + 2, S + 3
    
def random_col(board):
    return randint(1, len(board[0]) - 1)

# %% [markdown]
# I imported the randint function onto ipython. Than using a for loop, I created a 10 by 10 board of "O"s. I than invited players to play the game, with the phrase, "Let's play Battleship!".  After, I randomly genearated a ship onto my board that is four spaces long in the vertical direction.

# %%
ship_row = random_row(board)
ship_col = random_col(board)

    
    # Everything from here on should go in your for loop!
    # Be sure to indent four spaces!
for turn in range(11):
    guess_row = int(raw_input("Guess Row:"))
    guess_col = int(raw_input("Guess Col:"))
    
    if guess_row in ship_row and guess_col == ship_col:
        print "Congratulations! You sunk my battleship!"
        
        board[guess_row][guess_col] = "Y"
        
        grid[guess_row, guess_col] = (255, 0, 0)
        grid.show()
         
    else:
        if (guess_row < 0 or guess_row > 10) or (guess_col < 0 or guess_col > 10):
            print "Oops, that's not even in the ocean."
        elif(board[guess_row][guess_col] == "X"):
            print "You guessed that one already."
        else:
            print "You missed my battleship!"
            board[guess_row][guess_col] = "X"
            grid[guess_row, guess_col] = (70, 130, 180)
            grid.show()
            if turn == 10:
                print "Game Over"
                print ship_row
                print ship_col
        # Print (turn + 1) here!
        print "turn", (turn + 1)

# %% [markdown]
# I gave the players ten turns (using range(11)) to guess the location of my ship in turns of rows and columns. If the player's guess is equal to the location of the ship, the game prints, "Congradulations! You sunk my battleship!".  I made the color of a shipwreck red. Than, if the ship was not sunk, I had an else statement that ensured that 1) the guess was in range of my grid 2) that guesses were not repeated 3) that an X  marked where I guessed on my board and a blue color marked where I placed my guess on the grid 4) that the game ended after 10 turns and printed out my row and column location for my ship.
